# %%
# !pip install pandas pyarrow kagglehub scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: pyarrow in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (20.0.0)
# Requirement already satisfied: kagglehub in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (0.3.12)
# Requirement already satisfied: scikit-learn in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (1.6.1)
# Requirement already satisfied: matplotlib in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: packaging in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from requests->kagglehub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from requests->kagglehub) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from requests->kagglehub) (2025.4.26)
# Requirement already satisfied: colorama in c:\users\bi23014\desktop\知的情報システム開発2\作業フォルダ\src\.venv\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("utsavdey1410/food-nutrition-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\bi23014\.cache\kagglehub\datasets\utsavdey1410\food-nutrition-dataset\versions\1

# %%
import pandas as pd
import os
import glob

path = "C:/Users/bi23014/.cache/kagglehub/datasets/utsavdey1410/food-nutrition-dataset/versions/1/FINAL FOOD DATASET"

all_files = glob.glob(os.path.join(path, "*.csv"))

df_list = []

for filename in all_files:
     df = pd.read_csv(filename)
     df_list.append(df)

merged_df = pd.concat(df_list, ignore_index=True)
merged_df.to_csv("merged_file.csv", index=False)  # ファイル名を必要に応じて変更してください

# %%
path = "./merged_file.csv"
df = pd.read_csv(path)

name = df["food"].to_list()
calory = df["Caloric Value"].to_list()
protein = df["Protein"].to_list()
fat = df["Fat"].to_list()
carbohydrates = df["Carbohydrates"].to_list()
fiber = df["Dietary Fiber"].to_list()
